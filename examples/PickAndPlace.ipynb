# %% [markdown]
# <a href="https://colab.research.google.com/github/Divi88ja/Amazon_book/blob/main/examples/PickAndPlace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `panda-gym` code example
#
# ## Install `panda-gym`

# %%
# %pip install panda-gym
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 8.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Interract

# %%
import gymnasium as gym
import panda_gym

env = gym.make("PandaPickAndPlace-v3", render_mode="rgb_array")
observation, info = env.reset()

images = [env.render()]
for _ in range(200):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    images.append(env.render())

    if terminated or truncated:
        observation, info = env.reset()
        images.append(env.render())

env.close()

# %% [markdown]
# ## Convert into animation

# %%
# %pip install numpngw
from numpngw import write_apng

write_apng("anim.png", images, delay=40)  # real-time rendering = 40 ms between frames

# %% [markdown]
# ## Show animation

# %%
from IPython.display import Image

Image(filename="anim.png")
